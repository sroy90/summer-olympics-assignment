# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
df = pd.read_csv("summer.csv")
df['City'].unique()
print(df['City'].unique())
print('Number of Cities are::')
print(len(df['City'].unique()))
# Out:
# ['Athens' 'Paris' 'St Louis' 'London' 'Stockholm' 'Antwerp' 'Amsterdam'
#  'Los Angeles' 'Berlin' 'Helsinki' 'Melbourne / Stockholm' 'Rome' 'Tokyo'
#  'Mexico' 'Munich' 'Montreal' 'Moscow' 'Seoul' 'Barcelona' 'Atlanta'
#  'Sydney' 'Beijing']
# Number of Cities are::
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("summer.csv")
df=df[df['Medal']=='Gold']
data=[]
for Sport in df['Sport'].unique():
    data.append([Sport , len(df[df['Sport']== Sport])])
data=pd.DataFrame(data, columns = ['sports','Gold'])
data = data.sort_values(by = 'Gold' , ascending = False ).head()
data.plot(x = 'sports' , y = 'Gold' , kind = 'bar' , figsize= (5,5) )

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("summer.csv")
data=[]
for Medal in df['Sport'].unique():
    data.append([Medal , len(df[df['Sport']== Medal])])
data=pd.DataFrame(data, columns = ['sports','medals'])
data = data.sort_values(by = 'medals' , ascending = False ).head()
data.plot(x = 'sports' , y = 'medals' , kind = 'bar' , figsize= (5,5) )

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("summer.csv")
data=[]
for Medal in df['Athlete'].unique():
    data.append([Medal , len(df[df['Athlete']== Medal])])
data=pd.DataFrame(data, columns = ['cun','mdl'])
data = data.sort_values(by = 'mdl' , ascending = False ).head()
data.plot(x = 'cun' , y = 'mdl' , kind = 'bar' , figsize= (16,6))

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("summer.csv")
df=df[df['Medal']=='Gold']
data=[]
for Athlete in df['Athlete'].unique():
    data.append([Athlete , len(df[df['Athlete']== Athlete])])
data=pd.DataFrame(data, columns = ['Athlete','Gold'])
data = data.sort_values(by = 'Gold' , ascending = False ).head()
data.plot(x = 'Athlete' , y = 'Gold' , kind = 'bar' , figsize= (5,10) )

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
import sys
import pandas as pd
df = pd.read_csv("summer.csv")
df=df[df['Medal']=='Gold']
a=df[df['Country']=='IND']
data=[]
for Year in a['Year'].unique():
    data.append([Year , len(a[df['Year'] == Year])])
data=pd.DataFrame(data, columns = ['Year','Gold'])
data = data.sort_values(by = 'Year' , ascending = True ).head(1)
print(data)
# Out:
#    Year  Gold
# 0  1928    15
# C:\Users\SOUGATA ROY\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
import pandas as pd
df = pd.read_csv("summer.csv")
data=[]
for Athlete in df['Event'].unique():
    data.append([Athlete , len(df[df['Event']== Athlete])])
data=pd.DataFrame(data, columns = ['Event','Athlete'])
data = data.sort_values(by = 'Athlete' , ascending = False ).head()
data.plot(x = 'Event' , y = 'Athlete' , kind = 'bar' , figsize= (15,6))

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
import sys
import pandas as pd
df = pd.read_csv("summer.csv")
df=df[df['Medal']=='Gold']
a=df[df['Gender']=='Women']
data=[]
for Sport in a['Sport'].unique():
    data.append([Sport , len(a[df['Sport']== Sport])])
data=pd.DataFrame(data, columns = ['sports','Gold'])
data = data.sort_values(by = 'Gold' , ascending = False ).head()
data.plot(x = 'sports' , y = 'Gold' , kind = 'bar' , figsize= (5,5) )
# Out:
# C:\Users\SOUGATA ROY\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
a
# Out:
#        Year       City          Sport           Discipline  \
# 417    1900      Paris           Golf                 Golf
# 641    1900      Paris         Tennis               Tennis
# 649    1900      Paris         Tennis               Tennis
# 710    1904   St Louis        Archery              Archery
# 713    1904   St Louis        Archery              Archery
# 730    1904   St Louis        Archery              Archery
# 731    1904   St Louis        Archery              Archery
# 732    1904   St Louis        Archery              Archery
# 733    1904   St Louis        Archery              Archery
# 1185   1908     London        Archery              Archery
# 1843   1908     London        Skating       Figure skating
# 1849   1908     London        Skating       Figure skating
# 1870   1908     London         Tennis               Tennis
# 1876   1908     London         Tennis               Tennis
# 1941   1912  Stockholm       Aquatics               Diving
# ...
